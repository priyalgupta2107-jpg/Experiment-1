# %% [markdown]
# Experiment 1: Introduction to Python
# Name: Priyal Gupta
# PRN:25070123087

# %%
# Experiment 1: Introduction to Python
x,y,z="Apple","Orange","Cherry"
print(x,y,z,sep="\n")
# Out:
# Apple
# Orange
# Cherry

# %%
x,y,z,w=2,2.5,"priyal",True
print(type(x),type(y),type(z),type(w),sep="\n")
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
a,b=10,5
print("Sum=",a+b,"\nSub=",a-b,"\nProd=",a*b,"\nDiv=",a/b,"\nexp=",a**b)
# Out:
# Sum= 15
# Sub= 5
# Prod= 50
# Div= 2.0
# exp= 100000

# %%
a=int(input("Enter the value of a: "))
b=int(input("Enter the value of b: "))
print("Sum=",a+b,"\nSub=",a-b,"\nProd=",a*b,"\nDiv=",a/b,"\nexp=",a**b)
# Out:
# Enter the value of a: 10
# Enter the value of b: 5
# Sum= 15
# Sub= 5
# Prod= 50
# Div= 2.0
# exp= 100000

# %%
import math
r=float(input("Enter the value of radius :"))
Area=math.pi*r**2
print(Area)
# Out:
# Enter the value of radius :2.1
# 13.854423602330987

# %%
import math
Value=math.log10(10)
print(Value)
# Out:
# 1.0

# %%
import math
Value=math.sin(math.radians(30))
print("Result:",Value)
# Out:
# Result: 0.49999999999999994

# %%
a=int(input("Enter a :"))
b=int(input("Enter b :"))
if b<a:
  print("b is less than a")

else:
  print("b is greater than a")
# Out:
# Enter a :5
# Enter b :7
# b is greater than a
